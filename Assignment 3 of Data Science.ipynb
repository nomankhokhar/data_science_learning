# %% [markdown]
# ## Exercise 1: Read Total profit of all months and show it using a line plot
# Total profit data provided for each month. Generated line plot must include the following
# properties: –
# - X label name = Month Number
# - Y label name = Total profit

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("matplotLib.csv")
data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
plt.plot(data.month_number , data.total_profit)

plt.title("Compnay Profit Per Month")
plt.xlabel("Month number")
plt.ylabel("Total Profit")
plt.show()

# %% [markdown]
# ## Exercise 2: Get total profit of all months and show line plot with the following Style
# properties
# Generated line plot must include following Style properties:
# - Line Style dotted and Line-color should be red
# - Show legend at the lower right location.
# - X label name = Month Number
# - Y label name = Sold units number
# - Add a circle marker.
# - Line marker color as read
# - Line width should be 3

# %%
plt.plot(data.month_number , data.total_profit , marker="o" , linestyle="--", color="red", markersize=8, markerfacecolor="black", linewidth=3)


plt.title("Company Saled data of last year")
plt.xlabel("Month number")
plt.ylabel("Sold Units number")
plt.legend(['Profit of last year'], loc='lower right')
plt.show()

# %% [markdown]
# ## Exercise 3: Read all product sales data and show it using a multiline plot
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate
# Plotline for each product ).

# %%
products = data.columns[1:7]

for product in products:
    plt.plot(data['month_number'], data[product], label=product + " sales data", marker='o', linewidth=3)

plt.xlabel('Month Number')
plt.ylabel('Sales Units in number...')
plt.title('Sales Data')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Exercise 4: Read toothpaste sales data of each month and show it using a scatter plot
# Also, add a grid in the plot. gridline style should “–“.

# %%
plt.scatter(data['month_number'],  data['toothpaste'])

plt.xlabel("Month Number")
plt.ylabel("Number of units Sold")
plt.title("Tooth paste Sales data")
plt.xticks(range(1, 13, 1))
plt.grid(True, linestyle=':',  linewidth=2)
plt.legend(["Tooth paste sales data"], loc="upper left", )

# %% [markdown]
# ## Exercise 5: Read face cream and facewash product sales data and show it using the bar
# chart
# The bar chart should display the number of units sold per month for each product. Add a separate
# bar for each product in the same chart

# %%
bar_positions = range(1, 13)
plt.bar(data['month_number'], data['facecream'], width=bar_width, label='Face Cream sales data')
plt.bar([pos + 0.3 for pos in bar_positions], data['facewash'], width=bar_width, label='Facewash sales data')

plt.xlabel('Month Number')
plt.ylabel('Units Sold in number')
plt.title('Facewash and facecream sales data')

plt.xticks(range(1, 13, 1))
plt.grid(True, linestyle=':',  linewidth=2)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Exercise 6: Read sales data of bathing soap of all months and show it using a bar chart.

# %%
bar_positions = range(1, 13)
plt.bar(data['month_number'], data['bathingsoap'], width=0.8)
plt.xlabel('Month Number')
plt.ylabel('Units Sold in number')
plt.title('bathingsoap sales data')

plt.xticks(range(1, 13, 1))
plt.grid(True, linestyle=':',  linewidth=2)
plt.legend(loc='upper left')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Exercise 7: Read the total profit of each month and show it using the histogram to see the

# %%
plt.hist(data['total_profit'])
plt.xlabel('profit range in dollar')
plt.ylabel('Actual Profit in dollar')
plt.title('Profit data')
plt.legend(['Profit data'], loc='upper left')
plt.show()

# %% [markdown]
# ## Exercise 8: Calculate total sale data for last year for each product and show it using a Pie
# chart
# Note: In Pie chart display Number of units sold per year for each product in percentage.
# The Pie chart should look like this

# %%
plt.figure(figsize=(7,7))

x10 = [12.3, 6.6, 24.9, 40.6, 9.0, 6.6]

labels = data.columns[1:7]
plt.figure(figsize=(7, 7))
plt.pie(x10, labels=labels, autopct='%1.1f%%',)
plt.legend(labels, loc='lower right')
plt.title('Sales Data')
plt.show()

# %% [markdown]
# ## Exercise 9: Read Bathing soap facewash of all months and display it using the Subplo

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(8, 10))

axes[0].plot(data['month_number'], data['bathingsoap'], marker='o',markersize=10, color='black', linewidth=4)
axes[0].set_title('Sales data of Bathing Soap')

axes[1].plot(data['month_number'], data['facewash'], marker='o', markersize=10 ,color='r',  linewidth=4)
axes[1].set_title('Sales data of facewash')
axes[1].set_xlabel('Month Number')
axes[1].set_ylabel('Units Sold in number')

plt.show()

# %% [markdown]
# ## Exercise Question 10: Read all product sales data and show it using the stack plot

# %%
products = data.columns[1:7]
plt.figure(figsize=(10, 6))

custom_colors = ['purple', '#00BFBF', 'red', 'black', 'green', 'yellow']

plt.stackplot(data['month_number'], *[data[product] for product in products], labels=products, colors=custom_colors)
plt.xlabel('Month Number')
plt.ylabel('Units Sold in number')
plt.title('All Product sales data using stack plot')

plt.legend(loc='upper left')
plt.show()
